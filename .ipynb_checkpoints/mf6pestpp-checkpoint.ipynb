# %%
import os
import sys
import flopy as fp
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import pyemu
from shutil import copyfile
plt.rcParams['font.size']=12

# %%
workspace = "workspace"
model_name = "mf6model"
exe_name="mf6.exe"

nrow = 280
ncol = 240

# %%
plt.imshow(fp.utils.HeadFile("workspace/{}.hds".format(model_name)).get_data((0,0))[0])
plt.colorbar()

# %%
sim = fp.mf6.MFSimulation.load(sim_ws=workspace)
m = sim.get_model(model_name)
sr = pyemu.helpers.SpatialReference.from_namfile(
        os.path.join(workspace, "{}.nam".format(model_name)),
        delr=m.dis.delr.array, delc=m.dis.delc.array)
# Out:
# loading simulation...
#   loading simulation name file...
#   loading tdis package...
#   loading model gwf6...
#     loading package dis...
#     loading package ic...
#     loading package npf...
#     loading package chd...
#     loading package riv...
#     loading package obs...
#     loading package oc...
#   loading ims package mf6model...
#    could not remove start_datetime

# %%
#sr=pyemu.utils.helpers.SpatialReference.set_spatialreference(xul=None, yul=None, xll=None, yll=None, rotation=0.0)

# %%
xul, yul = 1098000, 1285000 # Model Origin

dxdy = 50 #grid spacing
delc = np.ones(nrow, dtype=float) * dxdy
delr = np.ones(ncol, dtype=float) * dxdy
rot = 0

sr = pyemu.helpers.SpatialReference(delr=delr, delc=delc, xul=xul, yul=yul, rotation=rot, epsg='3116')
sr
# Out:
# xul:1098000; yul:1285000; rotation:0; proj4_str:+init=epsg:3116; units:meters; lenuni:2; length_multiplier:1.0

# %%
file = "heads.csv"
fileout = "workspace/heads.csv"
os.remove(fileout)
copyfile(file, fileout) # copy 

# empty pst from object
template_ws = "template"
pf = pyemu.utils.PstFrom(original_d=workspace, new_d=template_ws,
                 remove_existing=True,
                 longnames=True, spatial_reference=sr,
                 zero_based=False)
# Out:
# 2021-02-20 21:30:09.779681 starting: opening PstFrom.log for logging
# 2021-02-20 21:30:09.780388 starting PstFrom process
# 2021-02-20 21:30:09.780388 starting: setting up dirs
# 2021-02-20 21:30:09.780388 starting: removing existing new_d 'template'
# 2021-02-20 21:30:09.807396 finished: removing existing new_d 'template' took: 0:00:00.027008
# 2021-02-20 21:30:09.807396 starting: copying original_d 'workspace' to new_d 'template'
# 2021-02-20 21:30:09.860410 finished: copying original_d 'workspace' to new_d 'template' took: 0:00:00.053014
# 2021-02-20 21:30:09.861410 finished: setting up dirs took: 0:00:00.081022

# %%
#add observation
df = pd.read_csv(os.path.join(template_ws,"heads.csv"),index_col=0)

hds_df = pf.add_observations("heads.csv",insfile="heads.csv.ins",index_cols="time",
                use_cols=list(df.columns.values),prefix="hds",obsgp=False)

case = "pest_test"
pf.build_pst("{}.pst".format(case))
# Out:
# 2021-02-20 21:30:09.982462 starting: adding observations from tabular output file
# 2021-02-20 21:30:09.982462 starting: reading list template\heads.csv
# 2021-02-20 21:30:09.985461 finished: reading list template\heads.csv took: 0:00:00.002999
# 2021-02-20 21:30:09.985461 starting: building insfile for tabular output file heads.csv
# 2021-02-20 21:30:09.991463 finished: building insfile for tabular output file heads.csv took: 0:00:00.006002
# 2021-02-20 21:30:09.991463 starting: adding observation from instruction file 'template\heads.csv.ins'
# 2021-02-20 21:30:09.997465 finished: adding observation from instruction file 'template\heads.csv.ins' took: 0:00:00.006002
# 2021-02-20 21:30:09.998465 finished: adding observations from tabular output file took: 0:00:00.016003
# noptmax:30, npar_adj:0, nnz_obs:33

# %%
ppspace1=30
a = ppspace1*3.0*50
v = pyemu.geostats.GauVario(contribution=1.0,a=a)
grid_gs1 = pyemu.geostats.GeoStruct(variograms=v, transform='log')

fig = plt.figure(figsize=(8,4))
grid_gs1.plot()
print("spatial variogram")
# Out:
# spatial variogram

# %%
ppspace2=15
a = ppspace2*3.0*50
v = pyemu.geostats.GauVario(contribution=1.0,a=a)
grid_gs2 = pyemu.geostats.GeoStruct(variograms=v, transform='log')

fig = plt.figure(figsize=(8,4))
grid_gs2.plot()
print("spatial variogram")
# Out:
# spatial variogram

# %%
# set an homogeneous k array (as initial value)
# k = 1e-4*np.ones([nrow,ncol])
# filnm = "k.txt"
# np.savetxt(os.path.join(template_ws,filnm),k)

# %%
# Model domain in txt file because the code for some reason is not respecting my m.dis.idomain in the pilot point section
# maxsize to check these matrices very well!
np.set_printoptions(threshold=sys.maxsize)

ib0=np.loadtxt(os.path.join(workspace,"mf6model.dis_idomain_layer0.txt"))
ib1=np.loadtxt(os.path.join(workspace,"mf6model.dis_idomain_layer1.txt"))
ib2=np.loadtxt(os.path.join(workspace,"mf6model.dis_idomain_layer2.txt"))
ib3=np.loadtxt(os.path.join(workspace,"mf6model.dis_idomain_layer3.txt"))

ib=[ib0,ib1,ib2,ib3]

# To make sure only greater than zero values are being considered in the pilot point automated placement for all layers
nlay=4
for i in range(0,nlay):
    ib[i][ib[i]==-1]=0

# %%
#Horizontal conductivity for the 4 layers
#layer1

pf.add_parameters(filenames="hk0.txt",par_type="constant",
                   par_name_base="kp0",pargp="hp1", zone_array=ib[0], spatial_reference=sr,
                   upper_bound=10.,lower_bound=0.1, ult_ubound=1.1921e-3,ult_lbound=1.1574e-8)

#layer2
pf.add_parameters(filenames="hk1.txt",par_type="pilotpoint",pp_space=ppspace2,
                   par_name_base="kp1",pargp="hp2", zone_array=ib[1], spatial_reference=sr,
                   upper_bound=10.,lower_bound=0.1,geostruct=grid_gs2, ult_ubound=1.1921e-3,ult_lbound=1.1921e-5)
#layer3
pf.add_parameters(filenames="hk2.txt",par_type="pilotpoint",pp_space=ppspace2,
                   par_name_base="kp2",pargp="hp3", zone_array=ib[2], spatial_reference=sr,
                   upper_bound=10.,lower_bound=0.1,geostruct=grid_gs2, ult_ubound=1.1574e-6,ult_lbound=1.1574e-8)

#layer4
pf.add_parameters(filenames="hk3.txt",par_type="pilotpoint",pp_space=ppspace1,
                   par_name_base="kp3",pargp="hp4", zone_array=ib[3], spatial_reference=sr,
                   upper_bound=10.,lower_bound=0.1,geostruct=grid_gs1, ult_ubound=4.167e-4,ult_lbound=4.167e-6)

#Vertical conductivity for the 4 layers
#layer1

pf.add_parameters(filenames="vk0.txt",par_type="constant",
                  par_name_base="kp0",pargp="hp1", zone_array=ib[0], spatial_reference=sr,
                  upper_bound=10.,lower_bound=0.1, ult_ubound=2.1991e-4,ult_lbound=1.0417e-8)

#layer2
pf.add_parameters(filenames="vk1.txt",par_type="pilotpoint",pp_space=ppspace2,
                  par_name_base="kp1",pargp="hp2", zone_array=ib[1], spatial_reference=sr,
                  upper_bound=10.,lower_bound=0.1,geostruct=grid_gs2, ult_ubound=2.1991e-4,ult_lbound=2.1991e-6)
#layer3
pf.add_parameters(filenames="vk2.txt",par_type="pilotpoint",pp_space=ppspace2,
                   par_name_base="kp2",pargp="hp3", zone_array=ib[2], spatial_reference=sr,
                   upper_bound=10.,lower_bound=0.1,geostruct=grid_gs2, ult_ubound=1.0417e-6,ult_lbound=1.0417e-8)
#layer4
pf.add_parameters(filenames="vk3.txt",par_type="pilotpoint",pp_space=ppspace1,
                   par_name_base="kp3",pargp="hp4", zone_array=ib[3], spatial_reference=sr,
                   upper_bound=10.,lower_bound=0.1,geostruct=grid_gs1, ult_ubound=1.736e-5,ult_lbound=1.736e-7)
# Out:
# 2021-02-20 21:30:13.918612 starting: adding constant type multiplier style parameters for file(s) ['hk0.txt']
# 2021-02-20 21:30:13.918612 starting: loading array template\hk0.txt
# 2021-02-20 21:30:13.981626 finished: loading array template\hk0.txt took: 0:00:00.063014
# 2021-02-20 21:30:13.982626 loaded array 'hk0.txt' of shape (280, 240)
# 2021-02-20 21:30:14.041639 starting: writing array-based template file 'kp0_inst0_constant.csv.tpl'
# 2021-02-20 21:30:14.041639 starting: writing template file kp0_inst0_constant.csv.tpl for ['kp0_inst:0']
# 2021-02-20 21:30:14.295696 finished: writing template file kp0_inst0_constant.csv.tpl for ['kp0_inst:0'] took: 0:00:00.254057
# 2021-02-20 21:30:14.295696 finished: writing array-based template file 'kp0_inst0_constant.csv.tpl' took: 0:00:00.254057
# 2021-02-20 21:30:14.338211 finished: adding constant type multiplier style parameters for file(s) ['hk0.txt'] took: 0:00:00.419599
# 2021-02-20 21:30:14.338211 starting: adding pilotpoint type multiplier style parameters for file(s) ['hk1.txt']
# 2021-02-20 21:30:14.338211 starting: loading array template\hk1.txt
# 2021-02-20 21:30:14.401224 finished: loading array template\hk1.txt took: 0:00:00.063013
# 2021-02-20 21:30:14.401224 loaded array 'hk1.txt' of shape (280, 240)
# 2021-02-20 21:30:14.460237 starting: writing array-based template file 'kp1_inst0_pilotpoint.csv.tpl'
# 2021-02-20 21:30:14.460237 starting: setting up pilot point parameters
# 2021-02-20 21:30:14.525252 37 pilot point parameters created
# 2021-02-20 21:30:14.525252 pilot point 'pargp':kp1_inst:0
# 2021-02-20 21:30:14.526252 finished: setting up pilot point parameters took: 0:00:00.066015
# 2021-02-20 21:30:14.532254 starting: calculating factors for pargp=kp1_inst:0
# 2021-02-20 21:30:14.533254 saving krige variance file:template\kp1_inst0pp.var.dat
# 2021-02-20 21:30:14.533254 saving krige factors file:template\kp1_inst0pp.fac
# starting interp point loop for 67200 points
# starting 0
# starting 1
# starting 2
# starting 3
# starting 4
# starting 5
# starting 6
# starting 7
# starting 8
# starting 9
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# took 31.531864 seconds
# 2021-02-20 21:30:46.488720 finished: calculating factors for pargp=kp1_inst:0 took: 0:00:31.956466
# 2021-02-20 21:30:46.489720 starting: writing array-based template file 'kp1_inst0pp.dat.tpl'
# 2021-02-20 21:30:46.494722 finished: adding pilotpoint type multiplier style parameters for file(s) ['hk1.txt'] took: 0:00:32.156511
# 2021-02-20 21:30:46.505724 starting: adding pilotpoint type multiplier style parameters for file(s) ['hk2.txt']
# 2021-02-20 21:30:46.505724 starting: loading array template\hk2.txt
# 2021-02-20 21:30:46.567737 finished: loading array template\hk2.txt took: 0:00:00.062013
# 2021-02-20 21:30:46.567737 loaded array 'hk2.txt' of shape (280, 240)
# 2021-02-20 21:30:46.628752 starting: writing array-based template file 'kp2_inst0_pilotpoint.csv.tpl'
# 2021-02-20 21:30:46.628752 starting: setting up pilot point parameters
# 2021-02-20 21:30:46.694765 37 pilot point parameters created
# 2021-02-20 21:30:46.695766 pilot point 'pargp':kp2_inst:0
# 2021-02-20 21:30:46.695766 finished: setting up pilot point parameters took: 0:00:00.067014
# 2021-02-20 21:30:46.702769 starting: writing array-based template file 'kp2_inst0pp.dat.tpl'
# 2021-02-20 21:30:46.707770 finished: adding pilotpoint type multiplier style parameters for file(s) ['hk2.txt'] took: 0:00:00.202046
# 2021-02-20 21:30:46.707770 starting: adding pilotpoint type multiplier style parameters for file(s) ['hk3.txt']
# 2021-02-20 21:30:46.708769 starting: loading array template\hk3.txt
# 2021-02-20 21:30:46.769783 finished: loading array template\hk3.txt took: 0:00:00.061014
# 2021-02-20 21:30:46.769783 loaded array 'hk3.txt' of shape (280, 240)
# 2021-02-20 21:30:46.830797 starting: writing array-based template file 'kp3_inst0_pilotpoint.csv.tpl'
# 2021-02-20 21:30:46.830797 starting: setting up pilot point parameters
# 2021-02-20 21:30:46.910815 48 pilot point parameters created
# 2021-02-20 21:30:46.911815 pilot point 'pargp':kp3_inst:0
# 2021-02-20 21:30:46.911815 finished: setting up pilot point parameters took: 0:00:00.081018
# 2021-02-20 21:30:46.919817 starting: calculating factors for pargp=kp3_inst:0
# 2021-02-20 21:30:46.919817 saving krige variance file:template\kp3_inst0pp.var.dat
# 2021-02-20 21:30:46.919817 saving krige factors file:template\kp3_inst0pp.fac
# starting interp point loop for 67200 points
# starting 0
# starting 1
# starting 2
# starting 3
# starting 4
# starting 5
# starting 6
# starting 7
# starting 8
# starting 9
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# took 53.069376 seconds
# 2021-02-20 21:31:42.181356 finished: calculating factors for pargp=kp3_inst:0 took: 0:00:55.261539
# 2021-02-20 21:31:42.181356 starting: writing array-based template file 'kp3_inst0pp.dat.tpl'
# 2021-02-20 21:31:42.186357 finished: adding pilotpoint type multiplier style parameters for file(s) ['hk3.txt'] took: 0:00:55.478587
# 2021-02-20 21:31:42.231366 starting: adding constant type multiplier style parameters for file(s) ['vk0.txt']
# 2021-02-20 21:31:42.231366 starting: loading array template\vk0.txt
# 2021-02-20 21:31:42.293380 finished: loading array template\vk0.txt took: 0:00:00.062014
# 2021-02-20 21:31:42.294381 loaded array 'vk0.txt' of shape (280, 240)
# 2021-02-20 21:31:42.356394 starting: writing array-based template file 'kp0_inst1_constant.csv.tpl'
# 2021-02-20 21:31:42.356394 starting: writing template file kp0_inst1_constant.csv.tpl for ['kp0_inst:1']
# 2021-02-20 21:31:42.618453 finished: writing template file kp0_inst1_constant.csv.tpl for ['kp0_inst:1'] took: 0:00:00.262059
# 2021-02-20 21:31:42.619453 finished: writing array-based template file 'kp0_inst1_constant.csv.tpl' took: 0:00:00.263059
# 2021-02-20 21:31:42.664464 finished: adding constant type multiplier style parameters for file(s) ['vk0.txt'] took: 0:00:00.433098
# 2021-02-20 21:31:42.664464 starting: adding pilotpoint type multiplier style parameters for file(s) ['vk1.txt']
# 2021-02-20 21:31:42.664464 starting: loading array template\vk1.txt
# 2021-02-20 21:31:42.726478 finished: loading array template\vk1.txt took: 0:00:00.062014
# 2021-02-20 21:31:42.726478 loaded array 'vk1.txt' of shape (280, 240)
# 2021-02-20 21:31:42.787491 starting: writing array-based template file 'kp1_inst1_pilotpoint.csv.tpl'
# 2021-02-20 21:31:42.787491 starting: setting up pilot point parameters
# 2021-02-20 21:31:42.864509 37 pilot point parameters created
# 2021-02-20 21:31:42.865509 pilot point 'pargp':kp1_inst:1
# 2021-02-20 21:31:42.865509 finished: setting up pilot point parameters took: 0:00:00.078018
# 2021-02-20 21:31:42.873512 starting: writing array-based template file 'kp1_inst1pp.dat.tpl'
# 2021-02-20 21:31:42.878513 finished: adding pilotpoint type multiplier style parameters for file(s) ['vk1.txt'] took: 0:00:00.214049
# 2021-02-20 21:31:42.878513 starting: adding pilotpoint type multiplier style parameters for file(s) ['vk2.txt']
# 2021-02-20 21:31:42.879512 starting: loading array template\vk2.txt
# 2021-02-20 21:31:42.943526 finished: loading array template\vk2.txt took: 0:00:00.064014
# 2021-02-20 21:31:42.943526 loaded array 'vk2.txt' of shape (280, 240)
# 2021-02-20 21:31:43.008541 starting: writing array-based template file 'kp2_inst1_pilotpoint.csv.tpl'
# 2021-02-20 21:31:43.009541 starting: setting up pilot point parameters
# 2021-02-20 21:31:43.084558 37 pilot point parameters created
# 2021-02-20 21:31:43.085559 pilot point 'pargp':kp2_inst:1
# 2021-02-20 21:31:43.085559 finished: setting up pilot point parameters took: 0:00:00.076018
# 2021-02-20 21:31:43.092560 starting: writing array-based template file 'kp2_inst1pp.dat.tpl'
# 2021-02-20 21:31:43.098561 finished: adding pilotpoint type multiplier style parameters for file(s) ['vk2.txt'] took: 0:00:00.220048
# 2021-02-20 21:31:43.098561 starting: adding pilotpoint type multiplier style parameters for file(s) ['vk3.txt']
# 2021-02-20 21:31:43.098561 starting: loading array template\vk3.txt
# 2021-02-20 21:31:43.163576 finished: loading array template\vk3.txt took: 0:00:00.065015
# 2021-02-20 21:31:43.163576 loaded array 'vk3.txt' of shape (280, 240)
# 2021-02-20 21:31:43.229590 starting: writing array-based template file 'kp3_inst1_pilotpoint.csv.tpl'
# 2021-02-20 21:31:43.229590 starting: setting up pilot point parameters
# 2021-02-20 21:31:43.311608 48 pilot point parameters created
# 2021-02-20 21:31:43.311608 pilot point 'pargp':kp3_inst:1
# 2021-02-20 21:31:43.312609 finished: setting up pilot point parameters took: 0:00:00.083019
# 2021-02-20 21:31:43.321612 starting: writing array-based template file 'kp3_inst1pp.dat.tpl'
# 2021-02-20 21:31:43.326612 finished: adding pilotpoint type multiplier style parameters for file(s) ['vk3.txt'] took: 0:00:00.228051

# %%
# add run model command
pf.mod_sys_cmds.append("..\mf6")
pf.build_pst("{}.pst".format(case))
# Out:
# noptmax:30, npar_adj:246, nnz_obs:33
# 2021-02-20 21:31:43.472645 forward_run line:pyemu.os_utils.run(r'..\mf6')

# %%
#Rewrite ins file because Pyemu isn't smart enough

file = "template/heads.csv.ins"
fileout = "template/heads2.csv.ins"
with open(file) as f:
    with open(fileout,"w") as fout:
        for i,line in enumerate(f):
            if i < 2:
                fout.write(line)
            if i > 1:
                for o,split in enumerate(line.split("w")):
                    if o == 1:
                        fout.write("~,~")
                    fout.write(split)
                        

copyfile(fileout, file) # copy 
os.remove(fileout) # delete tmp file

# %%
pst = pf.build_pst("{}.pst".format(case))
cov = pf.build_prior()
x = cov.x.copy()
x[x==0.0] = np.NaN
fig,ax = plt.subplots(1,1,figsize=(7,7))
g = ax.imshow(x)
# Out:
# noptmax:30, npar_adj:246, nnz_obs:33
# 2021-02-20 21:31:43.656687 WARNING: sys_cmd 'pyemu.os_utils.run(r'..\mf6')
# ' already in sys cmds, skipping...
# 2021-02-20 21:31:43.668689 starting: building prior covariance matrix
# 2021-02-20 21:31:43.723701 saving prior covariance matrix to file template\pest_test.prior.cov
# 2021-02-20 21:31:43.770711 finished: building prior covariance matrix took: 0:00:00.102022

# %%
t_d = "template"
m_d = "master_glm"

pst.control_data.noptmax = 0 # just a run
pst.write(os.path.join(t_d,"{}.pst".format(case)))
# Out:
# noptmax:0, npar_adj:244, nnz_obs:33

# %%
# calculate
n = 10 #select number of workers
pyemu.os_utils.start_workers(t_d,"../pestpp-glm.exe","{}.pst".format(case),num_workers=n,worker_root=".",master_dir=m_d)

# %%
pst.control_data.noptmax = -1 # FOR JACOBIAN
pst.write(os.path.join(t_d,"{}.pst".format(case)))
pyemu.os_utils.start_workers(t_d,"../pestpp-glm.exe","{}.pst".format(case),num_workers=n,worker_root=".",master_dir=m_d)
# Out:
# noptmax:-1, npar_adj:244, nnz_obs:33

# %%
t_d ="master_glm"
case="pest_test"
pst = pyemu.Pst(os.path.join(t_d,"{}.pst".format(case)))
pst.write_par_summary_table(filename="none")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-199-446dd6df04f0> in <module>
#       1 t_d ="master_glm"
#       2 case="pest_test"
# ----> 3 pst = pyemu.Pst(os.path.join(t_d,"{}.pst".format(case)))
#       4 pst.write_par_summary_table(filename="none")
#
# C:\ProgramData\Anaconda3\lib\site-packages\pyemu\pst\pst_handler.py in __init__(self, filename, load, resfile)
#     109         if load:
#     110             if not os.path.exists(filename):
# --> 111                 raise Exception("pst file not found:{0}".format(filename))
#     112
#     113             self.load(filename)
#
# Exception: pst file not found:master_glm\pest_test.pst

# %%
pst.control_data.noptmax = 15
pst.control_data.pestmode = "regularization"

pst.pestpp_options["n_iter_base"] = 1 
pst.pestpp_options["n_iter_super"] = 4 
# pst.pestpp_options["glm_num_reals"] = 300 
#
pst.pestpp_options["parcov"] = "{}.prior.cov".format(case) 
pst.pestpp_options["base_jacobian"] = "{}.jcb".format(case) 
pst.write(os.path.join(t_d,"{}.pst".format(case)))
pyemu.helpers.zero_order_tikhonov(pst)
# Out:
# noptmax:2, npar_adj:244, nnz_obs:33

# %%
m_d = "master_glm_run"
pyemu.os_utils.start_workers(t_d,"../pestpp-glm","{}.pst".format(case),num_workers=n,worker_root=".",
                           master_dir=m_d)

# %%
pst_a = pyemu.Pst(os.path.join(m_d,"{}.pst".format(case)))
pst_a.plot(kind='1to1')
# Out:
# [<Figure size 576x756 with 0 Axes>, <Figure size 576x756 with 8 Axes>]

# %%
# df = df=pd.read_csv(os.path.join(m_d,"{}.post.obsen.csv".format(case)),index_col=0)
# oe = pyemu.ObservationEnsemble.from_dataframe(pst=pst,df=df)
# ax = oe.phi_vector.hist()

# %%
# dfp = df=pd.read_csv(os.path.join(m_d,"{}.par.usum.csv".format(case)),index_col=0)
# 10**dfp["post_mean"]
# Out:
# name
# KP1_INST:0_I:67_J:127     10.000000
# KP1_INST:0_I:67_J:157     10.000000
# KP1_INST:0_I:82_J:142     10.000000
# KP1_INST:0_I:82_J:157     10.000000
# KP1_INST:0_I:82_J:172     10.000000
#                             ...
# KP3_INST:1_I:255_J:75     10.000000
# KP3_INST:1_I:255_J:105     6.577790
# KP3_INST:1_I:255_J:135     0.100000
# KP3_INST:1_I:255_J:165     0.100000
# KP3_INST:1_I:255_J:195     0.889577
# Name: post_mean, Length: 244, dtype: float64

# %%
# plt.hist(10**dfp["post_mean"],bins=30)

# %%
pst.parameter_data.parval1 = 10**dfp["post_mean"].values
pst.control_data.noptmax = 0 # one run with optimal parameters

pst.write(os.path.join(t_d,"{}.pst".format(case)))

pyemu.os_utils.run("..\pestpp-glm.exe {}".format(case),cwd=t_d)
# Out:
# noptmax:0, npar_adj:244, nnz_obs:33

# %%
fig,ax = plt.subplots(1,2,figsize=(15,5))

# inversion
g= ax[0].imshow(np.log10(np.loadtxt(os.path.join(t_d,"hk3.txt"))))
plt.colorbar(g,ax=ax[0])
plt.title("k after inversion")

a=ax[1].contour(np.flipud(np.log10(np.loadtxt(os.path.join(t_d,"hk3.txt")))))
ax[1].set_aspect("equal")
plt.colorbar(a,ax=ax[1])
plt.title("k after inversion")
# Out:
# Text(0.5, 1.0, 'k after inversion')

# %%
fig,ax = plt.subplots(1,2,figsize=(15,5))

# inversion
g= ax[0].imshow(np.log10(np.loadtxt(os.path.join("workspace","hk3.txt"))))
plt.colorbar(g,ax=ax[0])
plt.title("k before inversion")

a=ax[1].contour(np.flipud(np.log10(np.loadtxt(os.path.join("workspace","hk0.txt")))))
ax[1].set_aspect("equal")
plt.colorbar(a,ax=ax[1])
plt.title("k before inversion")
# Out:
# Text(0.5, 1.0, 'k before inversion')

# %%
pst_a.plot()
